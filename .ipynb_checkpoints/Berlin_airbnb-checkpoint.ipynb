# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline
import seaborn as sns
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#Load in the data

df_calendar = pd.read_csv('/Users/Caddi/Data/BerlinAirbnb/calendar.csv')
df_listings = pd.read_csv('/Users/Caddi/Data/BerlinAirbnb/listings.csv')
df_reviews = pd.read_csv('/Users/Caddi/Data/BerlinAirbnb/reviews.csv')

# %%
df_listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2695   https://www.airbnb.com/rooms/2695  20190514043746   2019-05-14
# 1   3176   https://www.airbnb.com/rooms/3176  20190514043746   2019-05-14
# 2   7071   https://www.airbnb.com/rooms/7071  20190514043746   2019-05-14
# 3   9991   https://www.airbnb.com/rooms/9991  20190514043746   2019-05-14
# 4  14325  https://www.airbnb.com/rooms/14325  20190514043746   2019-05-14
#
#                                   name  \
# 0   Prenzlauer Berg close to Mauerpark
# 1      Fabulous Flat in great Location
# 2     BrightRoom with sunny greenview!
# 3  Geourgeous flat - outstanding views
# 4         Apartment in Prenzlauer Berg
#
#                                              summary  \
# 0                                                NaN
# 1  This beautiful first floor apartment  is situa...
# 2  Cozy and large room in the beautiful district ...
# 3  4 bedroom with very large windows and outstand...
# 4  The apartment is located on the upper second f...
#
#                                                space  \
# 0  In the summertime we are spending most of our ...
# 1  1st floor (68m2) apartment on Kollwitzplatz/ P...
# 2  The BrightRoom is an approx. 20 sqm (215ft²), ...
# 3  THE APPARTMENT - 4 bedroom (US, Germany: 5 roo...
# 4  The apartment is located on the south-facing s...
#
#                                          description experiences_offered  \
# 0  In the summertime we are spending most of our ...                none
# 1  This beautiful first floor apartment  is situa...                none
# 2  Cozy and large room in the beautiful district ...                none
# 3  4 bedroom with very large windows and outstand...                none
# 4  The apartment is located on the upper second f...                none
#
#                                neighborhood_overview        ...          \
# 0                                                NaN        ...
# 1  The neighbourhood is famous for its variety of...        ...
# 2  Great neighborhood with plenty of Cafés, Baker...        ...
# 3  Prenzlauer Berg is an amazing neighbourhood wh...        ...
# 4                                                NaN        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f                     moderate
# 1                f                        f  strict_14_with_grace_period
# 2                f                        f                     moderate
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               2
# 3                               1
# 4                               4
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            4
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            2
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.67
# 1                                            0               1.19
# 2                                            0               1.93
# 3                                            0               0.13
# 4                                            0               0.21
#
# [5 rows x 106 columns]

# %% [markdown]
# In a first step, we will explore the datasets.

# %%
# First, the listings data
# Print rows and columns in calendar data set
print("Number of rows and columns: ", df_listings.shape)
# Assess null values
print(df_listings.isnull().sum())
# Out:
# Number of rows and columns:  (23536, 106)
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# name                                               54
# summary                                          1069
# space                                            8410
# description                                       297
# experiences_offered                                 0
# neighborhood_overview                           10776
# notes                                           15779
# transit                                          9289
# access                                          12215
# interaction                                     11986
# house_rules                                     11540
# thumbnail_url                                   23536
# medium_url                                      23536
# picture_url                                         0
# xl_picture_url                                  23536
# host_id                                             0
# host_url                                            0
# host_name                                          21
# host_since                                         21
# host_location                                     113
# host_about                                      11791
# host_response_time                              10490
# host_response_rate                              10490
# host_acceptance_rate                            23536
# host_is_superhost                                  21
# host_thumbnail_url                                 21
#                                                 ...
# has_availability                                    0
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# first_review                                     4156
# last_review                                      4156
# review_scores_rating                             4622
# review_scores_accuracy                           4648
# review_scores_cleanliness                        4644
# review_scores_checkin                            4666
# review_scores_communication                      4650
# review_scores_location                           4665
# review_scores_value                              4668
# requires_license                                    0
# license                                         21345
# jurisdiction_names                              23536
# instant_bookable                                    0
# is_business_travel_ready                            0
# cancellation_policy                                 0
# require_guest_profile_picture                       0
# require_guest_phone_verification                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                4156
# Length: 106, dtype: int64

# %%
#Find columns with many missing values
df_listings.isna().mean()
# Out:
# id                                              0.000000
# listing_url                                     0.000000
# scrape_id                                       0.000000
# last_scraped                                    0.000000
# name                                            0.002294
# summary                                         0.045420
# space                                           0.357325
# description                                     0.012619
# experiences_offered                             0.000000
# neighborhood_overview                           0.457852
# notes                                           0.670420
# transit                                         0.394672
# access                                          0.518992
# interaction                                     0.509262
# house_rules                                     0.490313
# thumbnail_url                                   1.000000
# medium_url                                      1.000000
# picture_url                                     0.000000
# xl_picture_url                                  1.000000
# host_id                                         0.000000
# host_url                                        0.000000
# host_name                                       0.000892
# host_since                                      0.000892
# host_location                                   0.004801
# host_about                                      0.500977
# host_response_time                              0.445700
# host_response_rate                              0.445700
# host_acceptance_rate                            1.000000
# host_is_superhost                               0.000892
# host_thumbnail_url                              0.000892
#                                                   ...
# has_availability                                0.000000
# availability_30                                 0.000000
# availability_60                                 0.000000
# availability_90                                 0.000000
# availability_365                                0.000000
# calendar_last_scraped                           0.000000
# number_of_reviews                               0.000000
# number_of_reviews_ltm                           0.000000
# first_review                                    0.176581
# last_review                                     0.176581
# review_scores_rating                            0.196380
# review_scores_accuracy                          0.197485
# review_scores_cleanliness                       0.197315
# review_scores_checkin                           0.198249
# review_scores_communication                     0.197570
# review_scores_location                          0.198207
# review_scores_value                             0.198334
# requires_license                                0.000000
# license                                         0.906909
# jurisdiction_names                              1.000000
# instant_bookable                                0.000000
# is_business_travel_ready                        0.000000
# cancellation_policy                             0.000000
# require_guest_profile_picture                   0.000000
# require_guest_phone_verification                0.000000
# calculated_host_listings_count                  0.000000
# calculated_host_listings_count_entire_homes     0.000000
# calculated_host_listings_count_private_rooms    0.000000
# calculated_host_listings_count_shared_rooms     0.000000
# reviews_per_month                               0.176581
# Length: 106, dtype: float64

# %%
# drop columns that have more than thresh percent of missing values
thresh = 0.75
droplist = []
for col in df_listings.columns:
    if df_listings[col].isna().mean() >= thresh :
        droplist.append(col)

   
df_listings_drop = df_listings.drop( droplist, axis =1 )

droplist=[]
for col in df_listings_drop.columns:
    if df_listings[col].nunique() == 1 :
        droplist.append(col)
df_listings_drop = df_listings.drop( droplist, axis =1 )

# %%
df_listings_drop.head()
# Out:
#       id                         listing_url  \
# 0   2695   https://www.airbnb.com/rooms/2695
# 1   3176   https://www.airbnb.com/rooms/3176
# 2   7071   https://www.airbnb.com/rooms/7071
# 3   9991   https://www.airbnb.com/rooms/9991
# 4  14325  https://www.airbnb.com/rooms/14325
#
#                                   name  \
# 0   Prenzlauer Berg close to Mauerpark
# 1      Fabulous Flat in great Location
# 2     BrightRoom with sunny greenview!
# 3  Geourgeous flat - outstanding views
# 4         Apartment in Prenzlauer Berg
#
#                                              summary  \
# 0                                                NaN
# 1  This beautiful first floor apartment  is situa...
# 2  Cozy and large room in the beautiful district ...
# 3  4 bedroom with very large windows and outstand...
# 4  The apartment is located on the upper second f...
#
#                                                space  \
# 0  In the summertime we are spending most of our ...
# 1  1st floor (68m2) apartment on Kollwitzplatz/ P...
# 2  The BrightRoom is an approx. 20 sqm (215ft²), ...
# 3  THE APPARTMENT - 4 bedroom (US, Germany: 5 roo...
# 4  The apartment is located on the south-facing s...
#
#                                          description  \
# 0  In the summertime we are spending most of our ...
# 1  This beautiful first floor apartment  is situa...
# 2  Cozy and large room in the beautiful district ...
# 3  4 bedroom with very large windows and outstand...
# 4  The apartment is located on the upper second f...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  The neighbourhood is famous for its variety of...
# 2  Great neighborhood with plenty of Cafés, Baker...
# 3  Prenzlauer Berg is an amazing neighbourhood wh...
# 4                                                NaN
#
#                                                notes  \
# 0                                                NaN
# 1  We welcome FAMILIES and cater especially for y...
# 2  I hope you enjoy your stay to the fullest! Ple...
# 3                                                NaN
# 4                                                NaN
#
#                                              transit  \
# 0  Within walking distance you'll find the S-Bahn...
# 1  We are 5 min walk  away from the tram M2, whic...
# 2  Best access to other parts of the city via pub...
# 3  Excellent location regarding public transport ...
# 4                                                NaN
#
#                                               access        ...         \
# 0  Außer deinem Zimmer kannst du noch die Küche u...        ...
# 1  The apartment will be entirely yours. We are c...        ...
# 2  The guests have access to the bathroom, a smal...        ...
# 3          All amenities shared - nothing off limits        ...
# 4                                                NaN        ...
#
#   jurisdiction_names instant_bookable          cancellation_policy  \
# 0                NaN                f                     moderate
# 1                NaN                f  strict_14_with_grace_period
# 2                NaN                f                     moderate
# 3                NaN                f  strict_14_with_grace_period
# 4                NaN                f  strict_14_with_grace_period
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              f                                f
# 4                              f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               2
# 3                               1
# 4                               4
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            4
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            2
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.67
# 1                                           0              1.19
# 2                                           0              1.93
# 3                                           0              0.13
# 4                                           0              0.21
#
# [5 rows x 100 columns]
